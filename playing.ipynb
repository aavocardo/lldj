# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x = np.arange(0, 1, 0.05)
y = [random.randint(1, 10) for _ in range(len(x))]

# %%
plt.plot(x,y)
plt.grid()
plt.figure(figsize=(40,20))
